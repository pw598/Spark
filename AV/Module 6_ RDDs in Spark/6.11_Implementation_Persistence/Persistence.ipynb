# %% [markdown]
# ---
#
#
# <center><h1> Persistence in RDDs </h1></center>
#
# ---
#
# * Spark RDD persistence is an optimization technique in which saves the result of RDD evaluation.
# * There are some advantages of RDD persistence in spark. It makes the whole system
#   * Time efficient
#   * Cost efficient
#
# ----
#
# #### `Create the Spark Context`
#
# ----

# %%
# importing the libraries
from pyspark.context import SparkContext

# %%
# create the spark context
sc #= SparkContext(appName="persistance_example")
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %% [markdown]
# ---
#
# In this Notebook, we are going to use 2 different text files
#
# * **`student_data.txt`**
#      * **Roll No**
#      * **Gender**
#      * **City**
#
# ---
#
# * **`marks.txt`**
#      * **Roll No**
#      * **Subject Code**
#      * **Marks**
#
# ---
#
# #### `Read the Student Dataset`
#
# ---

# %%
# create the rdd of the student dataset
students_data = sc.textFile('dataset/student_data.txt')

# %%
# top 5 rows
students_data.take(5)
# Out:
# ['IND2021100000 Others Delhi',
#  'IND2021100001 Female Gurgaon',
#  'IND2021100002 Male Mumbai',
#  'IND2021100003 Male Pune',
#  'IND2021100004 Male Mumbai']

# %% [markdown]
# ---
#
# Now, in the text file, all the columns are separated by space. So, first we have to use the map function to split it.
#
# ---
#
# #### `Split each row by space`
#
# ---

# %%
# split each row by space
students_data = students_data.map(lambda x: x.split(' '))

# %%
# view the top 5 rows
students_data.take(5)
# Out:
# [['IND2021100000', 'Others', 'Delhi'],
#  ['IND2021100001', 'Female', 'Gurgaon'],
#  ['IND2021100002', 'Male', 'Mumbai'],
#  ['IND2021100003', 'Male', 'Pune'],
#  ['IND2021100004', 'Male', 'Mumbai']]

# %% [markdown]
# ---
#
# Now, we will create the pair RDD of it, making the key as `student roll no` and (`gender`, `city`) as the values.
#
# ---
#
# #### `Creating the Pair RDDs`
#
# ---

# %%
# creating the Pair RDDs
students_data = students_data.map(lambda x: (x[0], (x[1], x[2])))

# %%
# view the top 5 rows
students_data.take(5)
# Out:
# [('IND2021100000', ('Others', 'Delhi')),
#  ('IND2021100001', ('Female', 'Gurgaon')),
#  ('IND2021100002', ('Male', 'Mumbai')),
#  ('IND2021100003', ('Male', 'Pune')),
#  ('IND2021100004', ('Male', 'Mumbai'))]

# %% [markdown]
# ---
#
# #### `Read the marks data`
#
#
# ---

# %%
# create the rdd of the marks data
marks = sc.textFile("dataset/marks.txt")

# %%
# view the top 5 rows
marks.take(5)
# Out:
# ['IND2021100000 PC001 56',
#  'IND2021100000 PC005 81',
#  'IND2021100000 PC033 83',
#  'IND2021100001 PC001 58',
#  'IND2021100001 PC005 81']

# %% [markdown]
# ---
#
# Now, in the text file, all the columns are separated by space. So, first we have to use the map function to split it.
#
# ---
#
# #### `Split each row by space`
#
# ----

# %%
# split each row by space
marks = marks.map(lambda x: x.split(' '))

# %%
# view the top 5 rows
marks.take(5)
# Out:
# [['IND2021100000', 'PC001', '56'],
#  ['IND2021100000', 'PC005', '81'],
#  ['IND2021100000', 'PC033', '83'],
#  ['IND2021100001', 'PC001', '58'],
#  ['IND2021100001', 'PC005', '81']]

# %% [markdown]
# ---
#
# We can see that the marks column in the above RDD is in string format. So, in the next step, we will type cast it into integer and also make it the pair RDD.
#
# ---
#
# #### `Type cast marks into integer and make pair RDD`
#
# ---

# %%
# type cast marks into integer 
marks_pair = marks.map(lambda x: (x[0], (x[1], int(x[2]))))

# %%
# view the top 5 views
marks_pair.take(5)
# Out:
# [('IND2021100000', ('PC001', 56)),
#  ('IND2021100000', ('PC005', 81)),
#  ('IND2021100000', ('PC033', 83)),
#  ('IND2021100001', ('PC001', 58)),
#  ('IND2021100001', ('PC005', 81))]

# %% [markdown]
# ---
#
# Now, for each roll no, we will find out the total marks and store it in front of each roll no. To do that we will use the `reduceByKey`
#
# ---

# %%
# total marks using the reduceByKey
total_marks = marks_pair.reduceByKey(lambda x, y: (x[0]+ " " + y[0] , x[1]+y[1]))

# %%
# view the top 5 rows
total_marks.take(5)
# Out:
# [('IND2021100001', ('PC001 PC005 PC033', 221)),
#  ('IND2021100002', ('PC001 PC005 PC033', 226)),
#  ('IND2021100005', ('PC001 PC005 PC033', 191)),
#  ('IND2021100006', ('PC001 PC005 PC033', 192)),
#  ('IND2021100007', ('PC001 PC005 PC033', 222))]

# %% [markdown]
# ---
#
# #### `Join the two Pair RDDS`
#
# ---
#
# Next, we will join the 2 pair RDDs, `students_data` & `total_marks`.
#
#
# ---

# %%
# join the pair RDDs
students_with_marks = students_data.join(total_marks)

# %%
# view the top 5
students_with_marks.take(5)
# Out:
# [('IND2021100002', (('Male', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021100005', (('Others', 'Mumbai'), ('PC001 PC005 PC033', 191))),
#  ('IND2021100015', (('Others', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021100022', (('Male', 'Gurgaon'), ('PC001 PC005 PC033', 240))),
#  ('IND2021100025', (('Male', 'Pune'), ('PC001 PC005 PC033', 179)))]

# %% [markdown]
# ---
#
# So, far we have done the following transformations on 2 different datasets.
#
# ---
#
# ![](images/level-1.png)
#
# ---

# %% [markdown]
# ---
#
# ### Now, we will do 2 more transformations on the joined data.
#
#    - We will find out the data of the `female` students.
#    - Next, we will find out the data of `female` students who are from `Pune`
#
# ---

# %% [markdown]
# ---
#
# ![](images/level-2.png)
#
# ---

# %% [markdown]
# ---
#
# #### `Data of female students`
#
# ---

# %%
# data of female students
students_with_data_female = students_with_marks.filter(lambda x : x[1][0][0] == "Female")

# %%
# collect the data
students_with_data_female.collect()
# Out:
# [('IND2021100031', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100038', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021100047', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021100052', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021100063', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100074', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100077', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100082', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100097', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100099', (('Female', 'Delhi'), ('PC001 PC005 PC033', 174))),
#  ('IND2021100103', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100116', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100130', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100153', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100156', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021100158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100169', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100193', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100214', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100243', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100289', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021100290', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021100303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100316', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100321', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021100327', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100356', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100360', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100401', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100411', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021100424', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100471', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100475', (('Female', 'Delhi'), ('PC001 PC005 PC033', 178))),
#  ('IND2021100487', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021100492', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100520', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100536', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100537', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021100548', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 218))),
#  ('IND2021100556', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021100558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100563', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021100566', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100568', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100604', (('Female', 'Delhi'), ('PC001 PC005 PC033', 230))),
#  ('IND2021100621', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100626', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021100647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 238))),
#  ('IND2021100669', (('Female', 'Delhi'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100696', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021100698', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021100734', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100752', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021100763', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100777', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021100783', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100796', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100808', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100818', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100819', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100842', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100848', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100849', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100860', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100901', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100905', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100910', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100929', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100939', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021100976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100979', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100980', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021101005', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101006', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101038', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 249))),
#  ('IND2021101059', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021101093', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101104', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101147', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101232', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021101259', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021101262', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101266', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101278', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101298', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 168))),
#  ('IND2021101355', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 254))),
#  ('IND2021101362', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021101376', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021101394', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101430', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101435', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101447', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021101470', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101479', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021101490', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021101508', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101517', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 244))),
#  ('IND2021101522', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101535', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101541', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101580', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021101582', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101583', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 241))),
#  ('IND2021101596', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101622', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101627', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101634', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101636', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101643', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101666', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101677', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021101690', (('Female', 'Delhi'), ('PC001 PC005 PC033', 172))),
#  ('IND2021101697', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021101703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021101723', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021101724', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021101767', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101773', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021101777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 236))),
#  ('IND2021101787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021101806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101817', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101828', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021101837', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021101839', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021101842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021101848', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021101943', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101973', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021101979', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101992', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021101997', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 180))),
#  ('IND2021102006', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102017', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102018', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102029', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021102031', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102104', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102109', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021102118', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102120', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021102135', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102140', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102144', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021102145', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102146', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021102175', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102183', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021102193', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021102198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021102213', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021102222', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102223', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102235', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 232))),
#  ('IND2021102240', (('Female', 'Delhi'), ('PC001 PC005 PC033', 168))),
#  ('IND2021102257', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102264', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 230))),
#  ('IND2021102289', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102297', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021102310', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 240))),
#  ('IND2021102315', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102325', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102334', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021102340', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102352', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102357', (('Female', 'Delhi'), ('PC001 PC005 PC033', 239))),
#  ('IND2021102365', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102377', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102392', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102395', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102419', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021102421', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102427', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102445', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021102462', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102469', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102477', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102499', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021102511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102516', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102555', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102565', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102617', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021102626', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102635', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102645', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021102652', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102653', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102654', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102657', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102663', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102675', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102713', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021102721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102728', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102754', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021102760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102763', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102773', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102776', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102788', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102792', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102816', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102817', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102833', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 227))),
#  ('IND2021102849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102861', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102869', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102906', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102936', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102956', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102959', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102962', (('Female', 'Delhi'), ('PC001 PC005 PC033', 218))),
#  ('IND2021102982', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021102983', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102990', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021102999', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103000', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103007', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103050', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103052', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021103075', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103076', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103101', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103118', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021103136', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103147', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103160', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103165', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103171', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021103173', (('Female', 'Delhi'), ('PC001 PC005 PC033', 251))),
#  ('IND2021103196', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103202', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103204', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021103216', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103218', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021103229', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103248', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021103268', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021103273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021103321', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103323', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103328', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103331', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021103343', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 180))),
#  ('IND2021103360', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103366', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021103394', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103436', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103442', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103443', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103465', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021103471', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103492', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021103499', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103501', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103503', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103509', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103510', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103519', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103522', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103535', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103551', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103556', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103567', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103573', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103575', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021103577', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021103580', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103606', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103614', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103638', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103649', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103655', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103661', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103664', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103670', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021103693', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103715', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103725', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103733', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103737', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103740', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021103759', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103769', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103779', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103781', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021103814', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103823', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103826', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103828', (('Female', 'Delhi'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103838', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103841', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103862', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103866', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021103875', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021103878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021103896', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103913', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103924', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103928', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 234))),
#  ('IND2021103934', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103938', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021103941', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103944', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103946', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103954', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021103999', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104007', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104034', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104035', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104091', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104102', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104110', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104127', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104143', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104168', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104178', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104180', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104187', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021104216', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104233', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104254', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021104255', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 174))),
#  ('IND2021104270', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104278', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021104288', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104290', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 184))),
#  ('IND2021104291', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104304', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104326', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104328', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021104345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104354', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 167))),
#  ('IND2021104364', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104379', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104380', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104402', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021104410', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021104418', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104430', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104453', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021104469', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104500', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104505', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021104513', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021104514', (('Female', 'Delhi'), ('PC001 PC005 PC033', 245))),
#  ('IND2021104527', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021104535', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104584', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104591', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104603', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104610', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021104633', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 228))),
#  ('IND2021104662', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104680', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104704', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104719', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104729', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104730', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104741', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104742', (('Female', 'Delhi'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104757', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104775', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104780', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104782', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021104791', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104810', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021104811', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 182))),
#  ('IND2021104850', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104856', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104861', (('Female', 'Delhi'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104868', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104880', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104885', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021104893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104907', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021104915', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021104921', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104933', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104940', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021104948', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021104983', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104984', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021104996', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105011', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 176))),
#  ('IND2021105067', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021105073', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105074', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105081', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105085', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105091', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 231))),
#  ('IND2021105098', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105106', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105109', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021105111', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105125', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021105128', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021105147', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105152', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021105159', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105187', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105189', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 169))),
#  ('IND2021105203', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021105210', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105221', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105223', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105228', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105235', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105240', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105243', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105253', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105259', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021105260', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105279', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105286', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105293', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021105295', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105325', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105328', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021105377', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105415', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021105430', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021105441', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021105449', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105460', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105465', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105485', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105495', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105516', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105527', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105539', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105543', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105558', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 241))),
#  ('IND2021105564', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021105570', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105594', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105598', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 185))),
#  ('IND2021105601', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105636', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105638', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105658', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105669', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105671', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021105681', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105686', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105709', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105726', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105732', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021105749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105762', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105785', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105793', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105794', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021105802', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105829', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 179))),
#  ('IND2021105830', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105831', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105838', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021105869', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105913', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105921', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105931', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105937', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105942', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021105954', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105957', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105958', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105959', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021105966', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105978', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105993', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105996', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106012', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 236))),
#  ('IND2021106018', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106039', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106042', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106059', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106096', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106100', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106104', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106113', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021106123', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106143', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106148', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106157', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106176', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106177', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106184', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106197', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106206', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106244', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106249', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106250', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021106253', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021106254', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106258', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106279', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106283', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106286', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106302', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106319', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106322', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021106343', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021106345', (('Female', 'Delhi'), ('PC001 PC005 PC033', 195))),
#  ('IND2021106358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106375', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021106390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106392', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 238))),
#  ('IND2021106403', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106427', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106454', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106459', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106470', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106471', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106484', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106491', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106502', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106504', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106509', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106512', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106571', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106582', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106595', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021106603', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106604', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 168))),
#  ('IND2021106619', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021106638', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106639', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106654', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106704', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106736', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106750', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021106780', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106783', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106808', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106810', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106852', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106866', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106870', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106907', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 222))),
#  ('IND2021106910', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106936', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021106942', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106948', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021106961', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106967', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106975', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106988', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021107008', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107012', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107016', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107017', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107036', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 174))),
#  ('IND2021107067', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107070', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021107076', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021107088', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107094', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107100', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107108', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107109', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 236))),
#  ('IND2021107111', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107113', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021107129', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107137', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021107138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021107142', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021107152', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107191', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021107200', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107221', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107225', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021107226', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107244', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021107268', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107296', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107316', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107339', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021107345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107367', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107371', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107381', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107405', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107407', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107415', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107422', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107426', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021107458', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021107468', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107475', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021107486', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107509', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021107511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021107558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107580', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107589', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107591', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 220))),
#  ('IND2021107599', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107617', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021107628', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021107647', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107660', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021107662', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 204))),
#  ('IND2021107665', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107666', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021107692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 173))),
#  ('IND2021107695', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107696', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021107703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107717', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107722', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107723', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021107771', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021107785', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107786', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107792', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107793', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
# ...
#  ('IND2021109006', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109007', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021109028', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109032', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021109037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109038', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109057', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109078', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021109079', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109121', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021109131', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109173', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021109200', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109209', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109210', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109236', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021109244', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021109267', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021109281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109295', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109304', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021109325', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109337', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109344', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021109345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021109352', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109366', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109393', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109403', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109426', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109481', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109482', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109484', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021109485', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109502', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109540', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109544', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021109573', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021109575', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021109579', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 168))),
#  ('IND2021109607', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109611', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109612', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021109641', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021109692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109715', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109716', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021109730', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109742', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021109763', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109765', (('Female', 'Delhi'), ('PC001 PC005 PC033', 243))),
#  ('IND2021109768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109778', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021109806', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109814', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021109824', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021109834', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109883', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021109963', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109978', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021109981', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110006', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110008', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110019', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 233))),
#  ('IND2021110022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110028', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021110039', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021110055', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021110057', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110078', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110079', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110105', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021110122', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110126', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110131', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110136', (('Female', 'Delhi'), ('PC001 PC005 PC033', 237))),
#  ('IND2021110164', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021110169', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021110181', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110191', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110201', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021110224', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110241', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110243', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110251', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021110266', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110270', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110278', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110286', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021110335', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110338', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021110339', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021110341', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110346', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021110348', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110353', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110356', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110359', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110400', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110423', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110442', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110455', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110466', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021110479', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110489', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 243))),
#  ('IND2021110500', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110524', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110546', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110558', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110599', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021110610', (('Female', 'Delhi'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110614', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110619', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110621', (('Female', 'Delhi'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110633', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110680', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 232))),
#  ('IND2021110706', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021110712', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110714', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110725', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021110741', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021110748', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110750', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 185))),
#  ('IND2021110751', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 250))),
#  ('IND2021110758', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110772', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021110790', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110797', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110803', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110834', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110835', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110837', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110845', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 204))),
#  ('IND2021110847', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110855', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110915', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110916', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110930', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110934', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110961', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021110974', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110983', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110988', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110994', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110998', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021111003', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021111042', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111045', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111053', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021111063', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111068', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021111073', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111078', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111114', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111115', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111130', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 205))),
#  ('IND2021111138', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111171', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111188', (('Female', 'Delhi'), ('PC001 PC005 PC033', 184))),
#  ('IND2021111198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111199', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111204', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021111228', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111236', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111237', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 175))),
#  ('IND2021111244', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111247', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021111259', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111308', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111312', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111330', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021111339', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 242))),
#  ('IND2021111340', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111375', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021111385', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021111391', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111448', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111452', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111462', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111467', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021111478', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021111491', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111496', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021111501', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111530', (('Female', 'Pune'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111552', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021111553', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021111556', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021111562', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111586', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111602', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111627', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111630', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021111638', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111643', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 227))),
#  ('IND2021111645', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111646', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111651', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021111669', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021111672', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 240))),
#  ...]

# %% [markdown]
# ---
#
# ![](images/female_data_1.png)
#
# ---

# %% [markdown]
# ---
#
#
#
# ---
#
# #### `Data of female students from Pune`
#
# ---

# %%
# data of female students from pune
students_with_data_pune = students_with_data_female.filter(lambda x: x[1][0][1] == "Pune")

# %%
# collect the data
students_with_data_pune.collect()
# Out:
# [('IND2021100116', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100169', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100289', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021100290', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021100321', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021100734', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100752', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021100763', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100860', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021101104', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101147', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101262', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101394', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101490', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021101541', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101580', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021101724', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101839', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021102018', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102031', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102120', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021102135', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102140', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102175', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102289', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102325', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102365', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102427', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102469', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102617', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021102626', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102635', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102645', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021102654', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102657', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102675', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102713', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021102763', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102776', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102869', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102983', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102990', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021102999', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103052', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021103165', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103171', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021103204', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021103218', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021103268', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021103321', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103366', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021103436', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103465', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021103471', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103501', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103556', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103573', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103759', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103779', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103781', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103875', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021103924', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103938', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021103999', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104034', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104091', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104216', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104270', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104291', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104364', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104410', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021104453', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021104469', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104513', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021104527', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021104782', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021104810', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021104850', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104868', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105067', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021105073', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105085', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105098', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105128', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021105187', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105203', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021105210', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105243', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105253', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105279', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105377', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105415', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021105430', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021105460', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105638', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105802', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105913', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105921', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105942', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021105957', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105966', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105996', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106018', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106096', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106100', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106104', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106113', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021106123', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106177', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106250', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021106253', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021106258', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106484', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106595', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021106638', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106704', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106808', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106910', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106936', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021106948', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021106988', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021107016', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107113', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021107137', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021107225', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021107316', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107371', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107407', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107599', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107660', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021107696', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021107813', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107843', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107940', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021108263', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021108291', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021108305', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021108406', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021108458', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021108475', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021108494', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021108517', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021108565', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021108631', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021108667', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021108777', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021108830', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021108897', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021108991', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021109006', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109032', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021109038', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109078', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021109236', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021109304', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021109337', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109352', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109393', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109484', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021109502', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109607', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109641', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021109730', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109742', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021110006', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110057', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110131', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110201', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021110241', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110243', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110266', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110400', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110455', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110500', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110524', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110725', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021110758', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110934', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110974', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110998', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021111045', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111228', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111244', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111312', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111467', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021111530', (('Female', 'Pune'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111556', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021111586', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111651', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021111713', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021111746', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021111925', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111948', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021111983', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021111999', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021112040', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021112046', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021112074', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021112136', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021112250', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021112323', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021112383', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021112399', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021112401', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021112410', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021112437', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021112451', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021112463', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021112484', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021112498', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021112507', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021112585', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021112659', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021112716', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021112802', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021112881', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021112960', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021113100', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021113116', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021113243', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021113280', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021113286', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021113314', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021113400', (('Female', 'Pune'), ('PC001 PC005 PC033', 167))),
#  ('IND2021113431', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021113452', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021113491', (('Female', 'Pune'), ('PC001 PC005 PC033', 166))),
#  ('IND2021113701', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021113719', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021113797', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021113899', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021114007', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021114063', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021114092', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021114186', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021114190', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021114223', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021114247', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021114299', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021114312', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021114340', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021114409', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021114422', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021114495', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021114532', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021114561', (('Female', 'Pune'), ('PC001 PC005 PC033', 246))),
#  ('IND2021114638', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021114688', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021114746', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021114836', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021114846', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021114932', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021114945', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021114977', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021115064', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021115147', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021115206', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021115222', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021115234', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021115306', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021115351', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021115397', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021115411', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021115422', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021115480', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021115533', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021115598', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021115625', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021115694', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021115717', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021115911', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021115956', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021115959', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021116012', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021116022', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021116080', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021116192', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021116225', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021116332', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021116397', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021116527', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021116533', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021116661', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021116699', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021116913', (('Female', 'Pune'), ('PC001 PC005 PC033', 239))),
#  ('IND2021116973', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021117033', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021117103', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021117114', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021117144', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021117175', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021117301', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021117364', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117376', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117420', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021117517', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021117638', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021117647', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021117671', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021117703', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021117758', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021117786', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117809', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021117837', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021117872', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021117952', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021117964', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021117968', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021117995', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021118106', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021118195', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021118241', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021118384', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021118439', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021118474', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021118488', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021118506', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021118594', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021118624', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021118656', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021118747', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021118924', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021119049', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021119095', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021119099', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119277', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119280', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119294', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021119352', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021119366', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021119370', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021119385', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119521', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119530', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021119531', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021119561', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021119620', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021119630', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021119688', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021119707', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021119724', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021119797', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119828', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021120014', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021120018', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021120047', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021120100', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021120143', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021120144', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021120200', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021120203', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021120233', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021120252', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021120263', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021120327', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021120350', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021120398', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021120458', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021120500', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021120511', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021120606', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021120649', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021120848', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021120875', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021120914', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021121141', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021121149', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021121182', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021121215', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021121229', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021121235', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021121274', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021121314', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021121319', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021121457', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021121533', (('Female', 'Pune'), ('PC001 PC005 PC033', 168))),
#  ('IND2021121539', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021121582', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021121967', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021122000', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122022', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021122146', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021122180', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021122233', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021122279', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021122307', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122422', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021122459', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122488', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021122632', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021122836', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021122968', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021123030', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021123032', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021123054', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021123062', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021123124', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021123185', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021123235', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123240', (('Female', 'Pune'), ('PC001 PC005 PC033', 252))),
#  ('IND2021123469', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021123498', (('Female', 'Pune'), ('PC001 PC005 PC033', 163))),
#  ('IND2021123566', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021123611', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021123658', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123696', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021123745', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021123758', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021123804', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123926', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021123975', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021123986', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021123993', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021124037', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021124166', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021124195', (('Female', 'Pune'), ('PC001 PC005 PC033', 176))),
#  ('IND2021124246', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021124566', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021124586', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021124637', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021124702', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021124761', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021124863', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021124921', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021125014', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021125043', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021125079', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021125131', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021125225', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021125287', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021125429', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021125459', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021125573', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021125645', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021125652', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021125676', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021125716', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021125789', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021125819', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021125858', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021125884', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021125904', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021125905', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021125927', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021126051', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021126216', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021126256', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021126411', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021126432', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021126589', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021126703', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021126746', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021126853', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021126996', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021127076', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021127084', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021127101', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021127133', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021127456', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021127462', (('Female', 'Pune'), ('PC001 PC005 PC033', 255))),
#  ('IND2021127505', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021127544', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021127578', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021127682', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021127752', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021127778', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021127937', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021128013', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021128083', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021128086', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021128162', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021128169', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021128283', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021128398', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021128532', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021128596', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021128786', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021128792', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021129000', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021129003', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021129029', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021129070', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021129118', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021129200', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021129308', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021129334', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021129348', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021129376', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021129394', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021129439', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021129537', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021129554', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021129581', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021129612', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021129630', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021129793', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021129803', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021129891', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021129949', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021129953', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021130030', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021130058', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021130131', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021130151', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021130338', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021130347', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021130420', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021130447', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021130498', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021130530', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021130542', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021130576', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021130585', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021130677', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021130823', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021130927', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021130999', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021131128', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021131209', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021131289', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021131295', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021131339', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021131375', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021131466', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021131547', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021131585', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021131736', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021131752', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021131828', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021131873', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021131976', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021131997', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021132043', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021132049', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021132170', (('Female', 'Pune'), ('PC001 PC005 PC033', 170))),
#  ('IND2021132180', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021132282', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021132337', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021132345', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021132477', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021132546', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021132664', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021132684', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021132823', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021132879', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021132896', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021133023', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021133150', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021133152', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021133153', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021133182', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021133191', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021133219', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021133351', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021133390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021133475', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021133530', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021133592', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021133646', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021133650', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021133668', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021133708', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021133752', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021133753', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021133765', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021133767', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021133781', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021133806', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021133832', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021133903', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021133909', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021134127', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021134147', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021134327', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021134328', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021134384', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021134412', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021134494', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021134535', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021134560', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021134981', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021135120', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021135213', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021135241', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135269', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135329', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021135336', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021135390', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021135404', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021135455', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021135463', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135594', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021135699', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021135752', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021135754', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021135867', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021135907', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021136011', (('Female', 'Pune'), ('PC001 PC005 PC033', 257))),
#  ('IND2021136016', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021136041', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021136059', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021136220', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021136260', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021136299', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021136425', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021136596', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021136706', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021136887', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021136930', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021136947', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021136961', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021137006', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021137042', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021137058', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021137101', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021137108', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021137164', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021137184', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021137270', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021137303', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021137328', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021137346', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021137441', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021137488', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021137565', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021137745', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021137780', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021137819', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021137886', (('Female', 'Pune'), ('PC001 PC005 PC033', 176))),
#  ('IND2021137894', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021137964', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021137974', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021138001', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021138201', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021138208', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021138403', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021138418', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021138420', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021138463', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021138592', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021138613', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021138621', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021138656', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021138698', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021138749', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021138766', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021138854', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021138890', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021138927', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021138937', (('Female', 'Pune'), ('PC001 PC005 PC033', 253))),
#  ('IND2021138948', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021139085', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021139178', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021139271', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021139308', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139445', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021139487', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021139489', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139584', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139587', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021139629', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021139677', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021139738', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021140068', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021140238', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021140256', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021140390', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021140412', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021140439', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021140448', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021140481', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021140485', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021140488', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021140498', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021140604', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021140616', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021140662', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021140697', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021140843', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021140890', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021140897', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021140950', (('Female', 'Pune'), ('PC001 PC005 PC033', 238))),
#  ('IND2021140981', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021141020', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
# ...
#  ('IND2021146437', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021146460', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021146556', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021146597', (('Female', 'Pune'), ('PC001 PC005 PC033', 163))),
#  ('IND2021146709', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146746', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021146766', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021146857', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146892', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021146920', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021146936', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146969', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021146973', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021146976', (('Female', 'Pune'), ('PC001 PC005 PC033', 246))),
#  ('IND2021147044', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021147096', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021147133', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021147202', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021147313', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021147393', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021147414', (('Female', 'Pune'), ('PC001 PC005 PC033', 169))),
#  ('IND2021147454', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021147458', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021147602', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021147650', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021147659', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021147691', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021147700', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021147715', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021147730', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021147749', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021147862', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021147908', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021147909', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021147913', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021147973', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021147976', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021148011', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021148040', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021148075', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021148090', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021148109', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021148198', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021148246', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021148295', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021148298', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021148317', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021148336', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021148384', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021148502', (('Female', 'Pune'), ('PC001 PC005 PC033', 239))),
#  ('IND2021148521', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021148543', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021148582', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021148611', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021148619', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021148652', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021148716', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021148821', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021148862', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021149021', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021149066', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021149075', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021149163', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021149218', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021149222', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021149224', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021149254', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021149316', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021149372', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021149440', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021149539', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021149741', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021149748', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021149844', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021149859', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021149965', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021150002', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021150109', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021150136', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021150207', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021150268', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021150270', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021150319', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021150352', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021150361', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021150614', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021150691', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021150699', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021150707', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021150725', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021150764', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021150767', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021150845', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021151091', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021151116', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021151141', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021151163', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021151256', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021151339', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021151380', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021151381', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021151435', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021151597', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021151626', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021151677', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021151824', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021151863', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021151980', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021152033', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021152096', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021152119', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021152151', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021152185', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021152221', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021152238', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021152308', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021152365', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021152382', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021152569', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021152714', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021152728', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021152782', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021152800', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021152951', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021152952', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021152995', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021153108', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021153150', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021153301', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021153315', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021153316', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021153377', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021153410', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021153413', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021153439', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021153456', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021153491', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021153583', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021153697', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021153778', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021153856', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021154027', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021154064', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021154075', (('Female', 'Pune'), ('PC001 PC005 PC033', 168))),
#  ('IND2021154143', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021154161', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021154162', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021154290', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021154298', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021154502', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021154512', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021154551', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021154568', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021154628', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021154672', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021154701', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021154755', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021154795', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021154821', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021154828', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021154839', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021154855', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021154862', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021154908', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021154937', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021154950', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021154956', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155008', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155197', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021155242', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021155249', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021155289', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021155295', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021155358', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021155415', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021155455', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021155485', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021155488', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155497', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021155537', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021155627', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021155767', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021155797', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155811', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021155830', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021155844', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155851', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155869', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021155877', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021155977', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021156107', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021156289', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021156415', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021156465', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021156471', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021156500', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021156516', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021156520', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021156639', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021156693', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021156821', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021156887', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021156956', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021156983', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021157012', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021157131', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021157379', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021157418', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021157442', (('Female', 'Pune'), ('PC001 PC005 PC033', 174))),
#  ('IND2021157456', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021157504', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021157555', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021157784', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021157790', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021157825', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021157887', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021158119', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021158174', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021158303', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021158369', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021158389', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021158725', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021158801', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021158865', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021158949', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021158955', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021159023', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021159208', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ...]

# %% [markdown]
# ---
#
# ![](images/female_from_pune_1.png)
#
# ---

# %% [markdown]
# ----
#
# Now, we can do a lot of things on the joined pair RDD like -
#
# * Find out the number of students from Mumbai?
# * Find out the number of Male students from Gurugram?
# * Find out the average marks of male & female students?
# * Find out the top 10 students in Pune?
#
# And a lot more. So, let's try to persist the joined Pair RDD so that it will take less time to compute the same operations.
#
#
# ----
#
#
# #### `Persist the Joined Pair RDD`
#
#
#
# ----

# %% [markdown]
# ---
#
# ![](images/level-3.png)
#
# ---

# %%
students_with_marks.persist()
# Out:
# PythonRDD[25] at RDD at PythonRDD.scala:53

# %% [markdown]
# ---
#
# **Now, we will do the same transformations on the persisted RDD**
#
#  - We will find out the data of the `female` students.
#  - Next, we will find out the data of `female` students who are from `Pune`
#
#
# ---
#
# #### `Data of female students from persisted RDD`
#
# ---

# %%
# data of female students 
students_with_data_female_persist = students_with_marks.filter(lambda x : x[1][0][0] == "Female")

# %%
# collect the data
students_with_data_female_persist.collect()
# Out:
# [('IND2021100031', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100038', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021100047', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021100052', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021100063', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100074', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100077', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100082', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100097', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100099', (('Female', 'Delhi'), ('PC001 PC005 PC033', 174))),
#  ('IND2021100103', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100116', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100130', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100153', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100156', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021100158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100169', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100193', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100214', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100243', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100289', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021100290', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021100303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100316', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100321', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021100327', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100356', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100360', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100401', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100411', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021100424', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100471', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100475', (('Female', 'Delhi'), ('PC001 PC005 PC033', 178))),
#  ('IND2021100487', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021100492', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100520', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100536', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100537', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021100548', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 218))),
#  ('IND2021100556', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021100558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100563', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021100566', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100568', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100604', (('Female', 'Delhi'), ('PC001 PC005 PC033', 230))),
#  ('IND2021100621', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100626', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021100647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 238))),
#  ('IND2021100669', (('Female', 'Delhi'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100696', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021100698', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021100734', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100752', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021100763', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100777', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021100783', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100796', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100808', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100818', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100819', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100842', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100848', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100849', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100860', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100901', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100905', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100910', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100929', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100939', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021100976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100979', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100980', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021101005', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101006', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101038', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 249))),
#  ('IND2021101059', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021101093', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101104', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101147', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101232', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021101259', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021101262', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101266', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101278', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101298', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 168))),
#  ('IND2021101355', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 254))),
#  ('IND2021101362', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021101376', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021101394', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101430', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101435', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101447', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021101470', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101479', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021101490', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021101508', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101517', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 244))),
#  ('IND2021101522', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101535', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101541', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101580', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021101582', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101583', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 241))),
#  ('IND2021101596', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101622', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101627', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101634', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101636', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101643', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101666', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101677', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021101690', (('Female', 'Delhi'), ('PC001 PC005 PC033', 172))),
#  ('IND2021101697', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021101703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021101723', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021101724', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021101767', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101773', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021101777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 236))),
#  ('IND2021101787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021101806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101817', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101828', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021101837', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021101839', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021101842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021101848', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021101943', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101973', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021101979', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101992', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021101997', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 180))),
#  ('IND2021102006', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102017', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102018', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102029', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021102031', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102104', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102109', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021102118', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102120', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021102135', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102140', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102144', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021102145', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102146', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021102175', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102183', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021102193', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021102198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021102213', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021102222', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102223', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102235', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 232))),
#  ('IND2021102240', (('Female', 'Delhi'), ('PC001 PC005 PC033', 168))),
#  ('IND2021102257', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102264', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 230))),
#  ('IND2021102289', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102297', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021102310', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 240))),
#  ('IND2021102315', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102325', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102334', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021102340', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102352', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102357', (('Female', 'Delhi'), ('PC001 PC005 PC033', 239))),
#  ('IND2021102365', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102377', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102392', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102395', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102419', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021102421', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102427', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102445', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021102462', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102469', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102477', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102499', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021102511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102516', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102555', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102565', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102617', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021102626', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102635', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102645', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021102652', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102653', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102654', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102657', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102663', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102675', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102713', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021102721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102728', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102754', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021102760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102763', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102773', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102776', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102788', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102792', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102816', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102817', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102833', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 227))),
#  ('IND2021102849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102861', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102869', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102906', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102936', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102956', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102959', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102962', (('Female', 'Delhi'), ('PC001 PC005 PC033', 218))),
#  ('IND2021102982', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021102983', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102990', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021102999', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103000', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103007', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103050', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103052', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021103075', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103076', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103101', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103118', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021103136', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103147', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103160', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103165', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103171', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021103173', (('Female', 'Delhi'), ('PC001 PC005 PC033', 251))),
#  ('IND2021103196', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103202', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103204', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021103216', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103218', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021103229', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103248', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021103268', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021103273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021103321', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103323', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103328', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103331', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021103343', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 180))),
#  ('IND2021103360', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103366', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021103394', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103436', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103442', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103443', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103465', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021103471', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103492', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021103499', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103501', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103503', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103509', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103510', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103519', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103522', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103535', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103551', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103556', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103567', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103573', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103575', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021103577', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021103580', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103606', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103614', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103638', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103649', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103655', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103661', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103664', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103670', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021103693', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103715', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103725', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103733', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103737', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103740', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021103759', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103769', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103779', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103781', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021103814', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103823', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103826', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103828', (('Female', 'Delhi'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103838', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103841', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103862', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103866', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021103875', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021103878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021103896', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103913', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103924', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103928', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 234))),
#  ('IND2021103934', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103938', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021103941', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103944', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103946', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103954', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021103999', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104007', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104034', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104035', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104091', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104102', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104110', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104127', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104143', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104168', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104178', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104180', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104187', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021104216', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104233', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104254', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021104255', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 174))),
#  ('IND2021104270', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104278', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021104288', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104290', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 184))),
#  ('IND2021104291', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104304', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104326', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104328', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021104345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104354', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 167))),
#  ('IND2021104364', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104379', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104380', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104402', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021104410', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021104418', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104430', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104453', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021104469', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104500', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104505', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021104513', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021104514', (('Female', 'Delhi'), ('PC001 PC005 PC033', 245))),
#  ('IND2021104527', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021104535', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104584', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104591', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104603', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104610', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021104633', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 228))),
#  ('IND2021104662', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104680', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104704', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104719', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104729', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104730', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104741', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104742', (('Female', 'Delhi'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104757', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104775', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104780', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104782', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021104791', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104810', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021104811', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 182))),
#  ('IND2021104850', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104856', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104861', (('Female', 'Delhi'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104868', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104880', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104885', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021104893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104907', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021104915', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021104921', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104933', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104940', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021104948', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021104983', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104984', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021104996', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105011', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 176))),
#  ('IND2021105067', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021105073', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105074', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105081', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105085', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105091', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 231))),
#  ('IND2021105098', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105106', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105109', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021105111', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105125', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021105128', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021105147', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105152', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021105159', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105187', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105189', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 169))),
#  ('IND2021105203', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021105210', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105221', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105223', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105228', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105235', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105240', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105243', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105253', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105259', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021105260', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105279', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105286', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105293', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021105295', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105325', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105328', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021105377', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105415', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021105430', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021105441', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021105449', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105460', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105465', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105485', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105495', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105516', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105527', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105539', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105543', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105558', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 241))),
#  ('IND2021105564', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021105570', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105594', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105598', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 185))),
#  ('IND2021105601', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105636', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105638', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105658', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105669', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105671', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021105681', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105686', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105709', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105726', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105732', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021105749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105762', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105785', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105793', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105794', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021105802', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105829', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 179))),
#  ('IND2021105830', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105831', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105838', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021105869', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105913', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105921', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105931', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105937', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105942', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021105954', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105957', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105958', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105959', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021105966', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105978', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105993', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105996', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106012', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 236))),
#  ('IND2021106018', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106039', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106042', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106059', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106096', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106100', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106104', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106113', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021106123', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106143', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106148', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106157', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106176', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106177', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106184', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106197', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106206', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106244', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106249', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106250', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021106253', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021106254', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106258', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106279', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106283', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106286', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106302', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106319', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106322', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021106343', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021106345', (('Female', 'Delhi'), ('PC001 PC005 PC033', 195))),
#  ('IND2021106358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106375', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021106390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106392', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 238))),
#  ('IND2021106403', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106427', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106454', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106459', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106470', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106471', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106484', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106491', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106502', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106504', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106509', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106512', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106571', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106582', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106595', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021106603', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106604', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 168))),
#  ('IND2021106619', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021106638', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106639', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106654', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106704', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106736', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106750', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021106780', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106783', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106808', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106810', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106852', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106866', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106870', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106907', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 222))),
#  ('IND2021106910', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106936', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021106942', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106948', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021106961', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106967', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106975', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106988', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021107008', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107012', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107016', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107017', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107036', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 174))),
#  ('IND2021107067', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107070', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021107076', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021107088', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107094', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107100', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107108', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107109', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 236))),
#  ('IND2021107111', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107113', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021107129', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107137', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021107138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021107142', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021107152', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107191', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021107200', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107221', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107225', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021107226', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107244', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021107268', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107296', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107316', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107339', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021107345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107367', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107371', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107381', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107405', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107407', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107415', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107422', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107426', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021107458', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021107468', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107475', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021107486', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107509', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021107511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021107558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107580', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107589', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107591', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 220))),
#  ('IND2021107599', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107617', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021107628', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021107647', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107660', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021107662', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 204))),
#  ('IND2021107665', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107666', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021107692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 173))),
#  ('IND2021107695', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107696', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021107703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107717', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107722', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107723', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021107771', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021107785', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107786', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107792', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107793', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
# ...
#  ('IND2021109006', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109007', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021109028', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109032', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021109037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109038', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109057', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109078', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021109079', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109121', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021109131', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109173', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021109200', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109209', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109210', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109236', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021109244', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021109267', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021109281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109295', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109304', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021109325', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109337', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109344', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021109345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021109352', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109366', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109393', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109403', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109426', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109481', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109482', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109484', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021109485', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109502', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109540', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109544', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021109573', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021109575', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021109579', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 168))),
#  ('IND2021109607', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109611', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109612', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021109641', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021109692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109715', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109716', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021109730', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109742', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021109763', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109765', (('Female', 'Delhi'), ('PC001 PC005 PC033', 243))),
#  ('IND2021109768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109778', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021109806', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109814', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021109824', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021109834', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109883', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021109963', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109978', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021109981', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110006', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110008', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110019', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 233))),
#  ('IND2021110022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110028', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021110039', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021110055', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021110057', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110078', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110079', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110105', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021110122', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110126', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110131', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110136', (('Female', 'Delhi'), ('PC001 PC005 PC033', 237))),
#  ('IND2021110164', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021110169', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021110181', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110191', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110201', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021110224', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110241', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110243', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110251', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021110266', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110270', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110278', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110286', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021110335', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110338', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021110339', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021110341', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110346', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021110348', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110353', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110356', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110359', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110400', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110423', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110442', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110455', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110466', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021110479', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110489', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 243))),
#  ('IND2021110500', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110524', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110546', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110558', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110599', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021110610', (('Female', 'Delhi'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110614', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110619', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110621', (('Female', 'Delhi'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110633', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110680', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 232))),
#  ('IND2021110706', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021110712', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110714', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110725', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021110741', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021110748', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110750', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 185))),
#  ('IND2021110751', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 250))),
#  ('IND2021110758', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110772', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021110790', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110797', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110803', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110834', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110835', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110837', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110845', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 204))),
#  ('IND2021110847', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110855', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110915', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110916', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110930', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110934', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110961', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021110974', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110983', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110988', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110994', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110998', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021111003', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021111042', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111045', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111053', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021111063', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111068', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021111073', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111078', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111114', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111115', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111130', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 205))),
#  ('IND2021111138', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111171', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111188', (('Female', 'Delhi'), ('PC001 PC005 PC033', 184))),
#  ('IND2021111198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111199', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111204', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021111228', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111236', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111237', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 175))),
#  ('IND2021111244', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111247', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021111259', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111308', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111312', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111330', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021111339', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 242))),
#  ('IND2021111340', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111375', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021111385', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021111391', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111448', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111452', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111462', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111467', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021111478', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021111491', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111496', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021111501', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111530', (('Female', 'Pune'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111552', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021111553', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021111556', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021111562', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111586', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111602', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111627', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111630', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021111638', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111643', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 227))),
#  ('IND2021111645', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111646', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111651', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021111669', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021111672', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 240))),
#  ...]

# %% [markdown]
# ---
#
# ![](images/data_of_female_persist_1.png)
#
# ---

# %%
# check again
students_with_data_female_persist.collect()
# Out:
# [('IND2021100031', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100038', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021100047', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021100052', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021100063', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100074', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100077', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100082', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100097', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100099', (('Female', 'Delhi'), ('PC001 PC005 PC033', 174))),
#  ('IND2021100103', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100116', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100130', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100153', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100156', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021100158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100169', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100193', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100214', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021100243', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100289', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021100290', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021100303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100316', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021100321', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021100327', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021100356', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100360', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100401', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100411', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021100424', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100471', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100475', (('Female', 'Delhi'), ('PC001 PC005 PC033', 178))),
#  ('IND2021100487', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021100492', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100520', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021100536', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021100537', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021100548', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 218))),
#  ('IND2021100556', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021100558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100563', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021100566', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100568', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100604', (('Female', 'Delhi'), ('PC001 PC005 PC033', 230))),
#  ('IND2021100621', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100626', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021100647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 238))),
#  ('IND2021100669', (('Female', 'Delhi'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100696', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021100698', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021100734', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100752', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021100763', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100777', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021100783', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100796', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100808', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021100818', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021100819', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 234))),
#  ('IND2021100842', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021100848', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021100849', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100860', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021100901', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021100905', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021100910', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021100929', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100939', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021100976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021100979', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100980', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021101005', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101006', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101038', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 249))),
#  ('IND2021101059', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021101093', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101104', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101147', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101232', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021101259', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021101262', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101266', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101278', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101298', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 168))),
#  ('IND2021101355', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 254))),
#  ('IND2021101362', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021101376', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021101394', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101430', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101435', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101447', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021101470', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021101479', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021101490', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021101508', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021101517', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 244))),
#  ('IND2021101522', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101535', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101541', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101580', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021101582', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021101583', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 241))),
#  ('IND2021101596', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101622', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021101627', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101634', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101636', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101643', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021101666', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101677', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021101678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021101690', (('Female', 'Delhi'), ('PC001 PC005 PC033', 172))),
#  ('IND2021101697', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021101703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 228))),
#  ('IND2021101718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021101723', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021101724', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021101767', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101773', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021101777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 236))),
#  ('IND2021101787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021101806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021101817', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021101828', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021101837', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021101839', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021101842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021101848', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021101943', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101973', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021101979', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021101992', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 226))),
#  ('IND2021101997', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 180))),
#  ('IND2021102006', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102017', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102018', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102029', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021102031', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102104', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102109', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021102118', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102120', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021102135', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102140', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102144', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 186))),
#  ('IND2021102145', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021102146', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021102175', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102183', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021102193', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021102198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021102213', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021102222', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102223', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021102235', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 232))),
#  ('IND2021102240', (('Female', 'Delhi'), ('PC001 PC005 PC033', 168))),
#  ('IND2021102257', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102264', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 230))),
#  ('IND2021102289', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102297', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021102310', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 240))),
#  ('IND2021102315', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102325', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102334', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021102340', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102352', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102357', (('Female', 'Delhi'), ('PC001 PC005 PC033', 239))),
#  ('IND2021102365', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102377', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102392', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102395', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102419', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021102421', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102427', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102445', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021102462', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021102469', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102477', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 192))),
#  ('IND2021102499', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021102511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102516', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021102555', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102565', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102617', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021102626', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102635', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102645', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021102652', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021102653', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102654', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102657', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102663', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102675', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102713', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021102721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102728', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021102754', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021102760', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 244))),
#  ('IND2021102763', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102773', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102776', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102788', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102792', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021102816', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021102817', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021102833', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 227))),
#  ('IND2021102849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102861', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102869', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102906', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102936', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102956', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102959', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021102962', (('Female', 'Delhi'), ('PC001 PC005 PC033', 218))),
#  ('IND2021102982', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021102983', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102990', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021102999', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103000', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103007', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103050', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103052', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021103075', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103076', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103101', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103118', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021103136', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103147', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103150', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103160', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103165', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103171', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021103173', (('Female', 'Delhi'), ('PC001 PC005 PC033', 251))),
#  ('IND2021103196', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103202', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103204', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021103216', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103218', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021103229', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103248', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021103268', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021103273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021103321', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103323', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103328', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103331', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021103343', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021103351', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 180))),
#  ('IND2021103360', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103366', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021103394', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103436', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103442', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103443', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103465', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021103471', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103492', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021103499', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103501', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103503', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103509', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103510', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103519', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103522', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103535', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021103551', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103556', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103567', (('Female', 'Delhi'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103573', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103575', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021103577', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021103580', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021103606', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021103614', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103638', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103649', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103655', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103661', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103664', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103670', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 232))),
#  ('IND2021103693', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021103715', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103725', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103733', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021103737', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021103740', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021103759', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103769', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021103777', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103779', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103781', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103787', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103806', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021103814', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103823', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103826', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021103828', (('Female', 'Delhi'), ('PC001 PC005 PC033', 171))),
#  ('IND2021103830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 241))),
#  ('IND2021103838', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103841', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103849', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103862', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021103866', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021103875', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021103878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021103896', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021103913', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103924', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103928', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 234))),
#  ('IND2021103934', (('Female', 'Delhi'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103938', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021103941', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021103944', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021103946', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103954', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021103999', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104007', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021104034', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104035', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104091', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104102', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104110', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104127', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104143', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104168', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104178', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104180', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104187', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021104216', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104233', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104254', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021104255', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 174))),
#  ('IND2021104270', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104278', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 179))),
#  ('IND2021104288', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104290', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 184))),
#  ('IND2021104291', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104304', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104326', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104328', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021104345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104354', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 167))),
#  ('IND2021104364', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104379', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104380', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021104402', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021104410', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021104418', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021104430', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104453', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021104469', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104500', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104505', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021104513', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021104514', (('Female', 'Delhi'), ('PC001 PC005 PC033', 245))),
#  ('IND2021104527', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021104535', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104584', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021104591', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021104603', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104610', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021104633', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 228))),
#  ('IND2021104662', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104680', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021104704', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104719', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104729', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021104730', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104741', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104742', (('Female', 'Delhi'), ('PC001 PC005 PC033', 188))),
#  ('IND2021104757', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 189))),
#  ('IND2021104775', (('Female', 'Delhi'), ('PC001 PC005 PC033', 212))),
#  ('IND2021104780', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104782', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021104791', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104810', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021104811', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021104830', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021104840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 182))),
#  ('IND2021104850', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104856', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104861', (('Female', 'Delhi'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104868', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021104880', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104885', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021104893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104907', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 242))),
#  ('IND2021104915', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021104921', (('Female', 'Delhi'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104932', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021104933', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021104940', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 225))),
#  ('IND2021104948', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021104983', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021104984', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021104996', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105011', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 176))),
#  ('IND2021105067', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021105073', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105074', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105081', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105085', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105091', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 231))),
#  ('IND2021105098', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105106', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105109', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021105111', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105125', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021105128', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021105147', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105152', (('Female', 'Delhi'), ('PC001 PC005 PC033', 189))),
#  ('IND2021105159', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105187', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105189', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 169))),
#  ('IND2021105203', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021105210', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105221', (('Female', 'Delhi'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105223', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105228', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105235', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105240', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105243', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105253', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105259', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 166))),
#  ('IND2021105260', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105279', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105286', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105293', (('Female', 'Delhi'), ('PC001 PC005 PC033', 187))),
#  ('IND2021105295', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105325', (('Female', 'Delhi'), ('PC001 PC005 PC033', 204))),
#  ('IND2021105328', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 193))),
#  ('IND2021105377', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105415', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021105430', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021105441', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021105449', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105460', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105465', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105485', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 229))),
#  ('IND2021105495', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105516', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105527', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105539', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105543', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105558', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 241))),
#  ('IND2021105564', (('Female', 'Delhi'), ('PC001 PC005 PC033', 238))),
#  ('IND2021105570', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105594', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105598', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 185))),
#  ('IND2021105601', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105636', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105638', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105652', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105658', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021105669', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105671', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021105681', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105686', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105709', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 224))),
#  ('IND2021105726', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105732', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021105749', (('Female', 'Delhi'), ('PC001 PC005 PC033', 183))),
#  ('IND2021105762', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105785', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105793', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021105794', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021105802', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105829', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 179))),
#  ('IND2021105830', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105831', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105838', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 230))),
#  ('IND2021105853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021105869', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105878', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021105893', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021105913', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105921', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105931', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021105937', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105942', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021105954', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105957', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105958', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105959', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 200))),
#  ('IND2021105966', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105978', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021105993', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021105996', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106012', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 236))),
#  ('IND2021106018', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106039', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106042', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106059', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106096', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106100', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106104', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106113', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021106123', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106143', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106148', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106157', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106176', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106177', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106184', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106186', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 202))),
#  ('IND2021106197', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106206', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106244', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106249', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106250', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021106253', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021106254', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021106258', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106261', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106279', (('Female', 'Delhi'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106283', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106286', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106302', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106319', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 219))),
#  ('IND2021106322', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 225))),
#  ('IND2021106343', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 231))),
#  ('IND2021106345', (('Female', 'Delhi'), ('PC001 PC005 PC033', 195))),
#  ('IND2021106358', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106375', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021106390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106392', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 238))),
#  ('IND2021106403', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106427', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106454', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106459', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106470', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 229))),
#  ('IND2021106471', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106484', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106491', (('Female', 'Delhi'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106502', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106504', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106509', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106512', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106571', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106582', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106595', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021106603', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 199))),
#  ('IND2021106604', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 168))),
#  ('IND2021106619', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021106638', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106639', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106654', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021106678', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021106704', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106718', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021106736', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106750', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021106780', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021106783', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106808', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106810', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021106852', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106866', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106870', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021106907', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 222))),
#  ('IND2021106910', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106936', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021106942', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021106948', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021106961', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 251))),
#  ('IND2021106967', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106975', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021106988', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021107008', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107012', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107016', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107017', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107036', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 174))),
#  ('IND2021107067', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107070', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021107076', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 171))),
#  ('IND2021107088', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107094', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107100', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107108', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107109', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 236))),
#  ('IND2021107111', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107113', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021107129', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 203))),
#  ('IND2021107137', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021107138', (('Female', 'Delhi'), ('PC001 PC005 PC033', 191))),
#  ('IND2021107142', (('Female', 'Delhi'), ('PC001 PC005 PC033', 227))),
#  ('IND2021107152', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107191', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 213))),
#  ('IND2021107200', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107221', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107225', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021107226', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107244', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021107268', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021107296', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107316', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107339', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107340', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021107345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021107367', (('Female', 'Delhi'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107371', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107381', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107405', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021107407', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107415', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107422', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107426', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 234))),
#  ('IND2021107458', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 246))),
#  ('IND2021107468', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 201))),
#  ('IND2021107475', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 183))),
#  ('IND2021107486', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107509', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021107511', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021107558', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107580', (('Female', 'Delhi'), ('PC001 PC005 PC033', 208))),
#  ('IND2021107589', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107591', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 220))),
#  ('IND2021107599', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107617', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021107628', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021107647', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021107660', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021107662', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 204))),
#  ('IND2021107665', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 223))),
#  ('IND2021107666', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021107692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 173))),
#  ('IND2021107695', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107696', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021107703', (('Female', 'Delhi'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107717', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021107720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107722', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021107723', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 184))),
#  ('IND2021107771', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021107785', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 182))),
#  ('IND2021107786', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107792', (('Female', 'Delhi'), ('PC001 PC005 PC033', 198))),
#  ('IND2021107793', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
# ...
#  ('IND2021109006', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109007', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 193))),
#  ('IND2021109028', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109032', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021109037', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109038', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109057', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109078', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021109079', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109121', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 190))),
#  ('IND2021109131', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109173', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 195))),
#  ('IND2021109200', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109209', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109210', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109236', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021109244', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021109267', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109273', (('Female', 'Delhi'), ('PC001 PC005 PC033', 240))),
#  ('IND2021109279', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 216))),
#  ('IND2021109281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 218))),
#  ('IND2021109295', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109304', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021109325', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109337', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109344', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 177))),
#  ('IND2021109345', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 247))),
#  ('IND2021109352', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109366', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109393', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109403', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109426', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021109481', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021109482', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109484', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021109485', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109502', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109524', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 217))),
#  ('IND2021109540', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109544', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021109573', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021109575', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021109579', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 168))),
#  ('IND2021109607', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109611', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109612', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 241))),
#  ('IND2021109641', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021109692', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109715', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109716', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 196))),
#  ('IND2021109720', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109721', (('Female', 'Delhi'), ('PC001 PC005 PC033', 202))),
#  ('IND2021109730', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109742', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021109763', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109765', (('Female', 'Delhi'), ('PC001 PC005 PC033', 243))),
#  ('IND2021109768', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109778', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109780', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 204))),
#  ('IND2021109806', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021109814', (('Female', 'Delhi'), ('PC001 PC005 PC033', 219))),
#  ('IND2021109824', (('Female', 'Delhi'), ('PC001 PC005 PC033', 244))),
#  ('IND2021109834', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021109840', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109842', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021109853', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109883', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021109963', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109976', (('Female', 'Delhi'), ('PC001 PC005 PC033', 210))),
#  ('IND2021109978', (('Female', 'Delhi'), ('PC001 PC005 PC033', 186))),
#  ('IND2021109981', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110006', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110008', (('Female', 'Delhi'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110014', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110019', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 233))),
#  ('IND2021110022', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110028', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021110039', (('Female', 'Delhi'), ('PC001 PC005 PC033', 200))),
#  ('IND2021110055', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021110057', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110078', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110079', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110105', (('Female', 'Delhi'), ('PC001 PC005 PC033', 197))),
#  ('IND2021110122', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110126', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110131', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110136', (('Female', 'Delhi'), ('PC001 PC005 PC033', 237))),
#  ('IND2021110164', (('Female', 'Delhi'), ('PC001 PC005 PC033', 235))),
#  ('IND2021110169', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 234))),
#  ('IND2021110181', (('Female', 'Delhi'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110191', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110201', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021110224', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110226', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110241', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110243', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110251', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 216))),
#  ('IND2021110266', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110270', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110278', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110286', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 199))),
#  ('IND2021110335', (('Female', 'Delhi'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110338', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 206))),
#  ('IND2021110339', (('Female', 'Delhi'), ('PC001 PC005 PC033', 182))),
#  ('IND2021110341', (('Female', 'Delhi'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110346', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021110348', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110353', (('Female', 'Delhi'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110356', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110359', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110400', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110423', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 191))),
#  ('IND2021110442', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110455', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110466', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 194))),
#  ('IND2021110479', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110489', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 223))),
#  ('IND2021110493', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 243))),
#  ('IND2021110500', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110524', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110525', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110546', (('Female', 'Delhi'), ('PC001 PC005 PC033', 207))),
#  ('IND2021110558', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110599', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 230))),
#  ('IND2021110610', (('Female', 'Delhi'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110614', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110619', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110621', (('Female', 'Delhi'), ('PC001 PC005 PC033', 217))),
#  ('IND2021110633', (('Female', 'Delhi'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110647', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110680', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110684', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 232))),
#  ('IND2021110706', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 227))),
#  ('IND2021110712', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110714', (('Female', 'Delhi'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110725', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021110741', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 244))),
#  ('IND2021110748', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110750', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 185))),
#  ('IND2021110751', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 250))),
#  ('IND2021110758', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110772', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 228))),
#  ('IND2021110790', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110797', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021110803', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 209))),
#  ('IND2021110834', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 181))),
#  ('IND2021110835', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 219))),
#  ('IND2021110837', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110845', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 204))),
#  ('IND2021110847', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 218))),
#  ('IND2021110855', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 198))),
#  ('IND2021110915', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021110916', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 224))),
#  ('IND2021110930', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 221))),
#  ('IND2021110934', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110961', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021110974', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110983', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021110988', (('Female', 'Delhi'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110994', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 202))),
#  ('IND2021110998', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021111003', (('Female', 'Delhi'), ('PC001 PC005 PC033', 199))),
#  ('IND2021111042', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111045', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111053', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 183))),
#  ('IND2021111063', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111068', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 196))),
#  ('IND2021111073', (('Female', 'Delhi'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111078', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111094', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111114', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111115', (('Female', 'Delhi'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111130', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 205))),
#  ('IND2021111138', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111158', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111171', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111188', (('Female', 'Delhi'), ('PC001 PC005 PC033', 184))),
#  ('IND2021111198', (('Female', 'Delhi'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111199', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111204', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 220))),
#  ('IND2021111228', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111236', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111237', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 175))),
#  ('IND2021111244', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111247', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 225))),
#  ('IND2021111259', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 203))),
#  ('IND2021111281', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111303', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111308', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 186))),
#  ('IND2021111312', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111330', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 231))),
#  ('IND2021111339', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 242))),
#  ('IND2021111340', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111375', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 216))),
#  ('IND2021111385', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 223))),
#  ('IND2021111391', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 235))),
#  ('IND2021111448', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111452', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111462', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 212))),
#  ('IND2021111467', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021111478', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 207))),
#  ('IND2021111491', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 213))),
#  ('IND2021111496', (('Female', 'Delhi'), ('PC001 PC005 PC033', 232))),
#  ('IND2021111501', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 214))),
#  ('IND2021111530', (('Female', 'Pune'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111552', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 191))),
#  ('IND2021111553', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 219))),
#  ('IND2021111556', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021111562', (('Female', 'Delhi'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111586', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111602', (('Female', 'Delhi'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111627', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111630', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 228))),
#  ('IND2021111638', (('Female', 'Delhi'), ('PC001 PC005 PC033', 190))),
#  ('IND2021111643', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 227))),
#  ('IND2021111645', (('Female', 'Gurgaon'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111646', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 192))),
#  ('IND2021111651', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021111669', (('Female', 'Bengaluru'), ('PC001 PC005 PC033', 233))),
#  ('IND2021111672', (('Female', 'Mumbai'), ('PC001 PC005 PC033', 240))),
#  ...]

# %% [markdown]
# ---
#
# ![](images/data_with_female_persist_again.png)
#
# ----

# %% [markdown]
# ----
#
# #### `Data of female students from Pune from persisted RDD`
#
# ---

# %%
# data of female students from pune
students_with_data_pune_persist = students_with_data_female_persist.filter(lambda x: x[1][0][1] == "Pune")

# %%
# collect the data
students_with_data_pune_persist.collect()
# Out:
# [('IND2021100116', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021100169', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021100289', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021100290', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021100321', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021100734', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021100752', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021100763', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021100860', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021101104', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021101147', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101262', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021101394', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021101490', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021101541', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021101580', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021101724', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021101839', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021102018', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021102031', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021102120', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021102135', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102140', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102175', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102289', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021102325', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021102365', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021102427', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102469', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021102617', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021102626', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021102635', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021102645', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021102654', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102657', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021102675', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021102713', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021102763', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021102776', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021102869', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021102983', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021102990', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021102999', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021103052', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021103165', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021103171', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021103204', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021103218', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021103268', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021103321', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021103366', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021103436', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103465', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021103471', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103501', (('Female', 'Pune'), ('PC001 PC005 PC033', 249))),
#  ('IND2021103556', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021103573', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103759', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021103779', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021103781', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021103875', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021103924', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021103938', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021103999', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021104034', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021104091', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021104216', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104270', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021104291', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021104364', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021104410', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021104453', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021104469', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021104513', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021104527', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021104782', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021104810', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021104850', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021104868', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021105067', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021105073', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021105085', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021105098', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021105128', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021105187', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021105203', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021105210', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021105243', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021105253', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021105279', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105377', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021105415', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021105430', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021105460', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021105638', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105802', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021105913', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021105921', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021105942', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021105957', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021105966', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021105996', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021106018', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106096', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021106100', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106104', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106113', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021106123', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021106177', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106250', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021106253', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021106258', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021106390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021106484', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021106595', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021106638', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021106704', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021106808', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021106910', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021106936', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021106948', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021106988', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021107016', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107113', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021107137', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021107225', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021107316', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021107371', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021107407', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021107599', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021107660', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021107696', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021107813', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021107843', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021107940', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021108263', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021108291', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021108305', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021108406', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021108458', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021108475', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021108494', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021108517', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021108565', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021108631', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021108667', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021108777', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021108830', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021108897', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021108991', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021109006', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021109032', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021109038', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021109078', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021109236', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021109304', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021109337', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021109352', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021109393', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021109484', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021109502', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021109607', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021109641', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021109730', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021109742', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021110006', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110057', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110131', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021110201', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021110241', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021110243', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021110266', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021110400', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021110455', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021110500', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021110524', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110725', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021110758', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021110934', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021110974', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021110998', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021111045', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021111228', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021111244', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021111312', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021111467', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021111530', (('Female', 'Pune'), ('PC001 PC005 PC033', 251))),
#  ('IND2021111556', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021111586', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021111651', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021111713', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021111746', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021111925', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021111948', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021111983', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021111999', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021112040', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021112046', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021112074', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021112136', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021112250', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021112323', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021112383', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021112399', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021112401', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021112410', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021112437', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021112451', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021112463', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021112484', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021112498', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021112507', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021112585', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021112659', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021112716', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021112802', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021112881', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021112960', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021113100', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021113116', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021113243', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021113280', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021113286', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021113314', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021113400', (('Female', 'Pune'), ('PC001 PC005 PC033', 167))),
#  ('IND2021113431', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021113452', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021113491', (('Female', 'Pune'), ('PC001 PC005 PC033', 166))),
#  ('IND2021113701', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021113719', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021113797', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021113899', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021114007', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021114063', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021114092', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021114186', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021114190', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021114223', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021114247', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021114299', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021114312', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021114340', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021114409', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021114422', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021114495', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021114532', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021114561', (('Female', 'Pune'), ('PC001 PC005 PC033', 246))),
#  ('IND2021114638', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021114688', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021114746', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021114836', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021114846', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021114932', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021114945', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021114977', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021115064', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021115147', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021115206', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021115222', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021115234', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021115306', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021115351', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021115397', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021115411', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021115422', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021115480', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021115533', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021115598', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021115625', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021115694', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021115717', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021115911', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021115956', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021115959', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021116012', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021116022', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021116080', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021116192', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021116225', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021116332', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021116397', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021116527', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021116533', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021116661', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021116699', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021116913', (('Female', 'Pune'), ('PC001 PC005 PC033', 239))),
#  ('IND2021116973', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021117033', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021117103', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021117114', (('Female', 'Pune'), ('PC001 PC005 PC033', 175))),
#  ('IND2021117144', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021117175', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021117301', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021117364', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117376', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117420', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021117517', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021117638', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021117647', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021117671', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021117703', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021117758', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021117786', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021117809', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021117837', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021117872', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021117952', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021117964', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021117968', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021117995', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021118106', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021118195', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021118241', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021118384', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021118439', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021118474', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021118488', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021118506', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021118594', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021118624', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021118656', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021118747', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021118924', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021119049', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021119095', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021119099', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119277', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119280', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119294', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021119352', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021119366', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021119370', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021119385', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119521', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021119530', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021119531', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021119561', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021119620', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021119630', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021119688', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021119707', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021119724', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021119797', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021119828', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021120014', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021120018', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021120047', (('Female', 'Pune'), ('PC001 PC005 PC033', 165))),
#  ('IND2021120100', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021120143', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021120144', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021120200', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021120203', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021120233', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021120252', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021120263', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021120327', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021120350', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021120398', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021120458', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021120500', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021120511', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021120606', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021120649', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021120848', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021120875', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021120914', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021121141', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021121149', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021121182', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021121215', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021121229', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021121235', (('Female', 'Pune'), ('PC001 PC005 PC033', 243))),
#  ('IND2021121274', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021121314', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021121319', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021121457', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021121533', (('Female', 'Pune'), ('PC001 PC005 PC033', 168))),
#  ('IND2021121539', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021121582', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021121967', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021122000', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122022', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021122146', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021122180', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021122233', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021122279', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021122307', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122422', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021122459', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021122488', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021122632', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021122836', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021122968', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021123030', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021123032', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021123054', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021123062', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021123124', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021123185', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021123235', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123240', (('Female', 'Pune'), ('PC001 PC005 PC033', 252))),
#  ('IND2021123469', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021123498', (('Female', 'Pune'), ('PC001 PC005 PC033', 163))),
#  ('IND2021123566', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021123611', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021123658', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123696', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021123745', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021123758', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021123804', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021123926', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021123975', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021123986', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021123993', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021124037', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021124166', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021124195', (('Female', 'Pune'), ('PC001 PC005 PC033', 176))),
#  ('IND2021124246', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021124566', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021124586', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021124637', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021124702', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021124761', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021124863', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021124921', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021125014', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021125043', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021125079', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021125131', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021125225', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021125287', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021125429', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021125459', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021125573', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021125645', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021125652', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021125676', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021125716', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021125789', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021125819', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021125858', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021125884', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021125904', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021125905', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021125927', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021126051', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021126216', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021126256', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021126411', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021126432', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021126589', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021126703', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021126746', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021126853', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021126996', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021127076', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021127084', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021127101', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021127133', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021127456', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021127462', (('Female', 'Pune'), ('PC001 PC005 PC033', 255))),
#  ('IND2021127505', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021127544', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021127578', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021127682', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021127752', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021127778', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021127937', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021128013', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021128083', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021128086', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021128162', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021128169', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021128283', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021128398', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021128532', (('Female', 'Pune'), ('PC001 PC005 PC033', 172))),
#  ('IND2021128596', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021128786', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021128792', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021129000', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021129003', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021129029', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021129070', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021129118', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021129200', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021129308', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021129334', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021129348', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021129376', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021129394', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021129439', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021129537', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021129554', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021129581', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021129612', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021129630', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021129793', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021129803', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021129891', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021129949', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021129953', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021130030', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021130058', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021130131', (('Female', 'Pune'), ('PC001 PC005 PC033', 240))),
#  ('IND2021130151', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021130338', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021130347', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021130420', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021130447', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021130498', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021130530', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021130542', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021130576', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021130585', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021130677', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021130823', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021130927', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021130999', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021131128', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021131209', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021131289', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021131295', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021131339', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021131375', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021131466', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021131547', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021131585', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021131736', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021131752', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021131828', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021131873', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021131976', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021131997', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021132043', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021132049', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021132170', (('Female', 'Pune'), ('PC001 PC005 PC033', 170))),
#  ('IND2021132180', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021132282', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021132337', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021132345', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021132477', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021132546', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021132664', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021132684', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021132823', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021132879', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021132896', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021133023', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021133150', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021133152', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021133153', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021133182', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021133191', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021133219', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021133351', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021133390', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021133475', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021133530', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021133592', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021133646', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021133650', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021133668', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021133708', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021133752', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021133753', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021133765', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021133767', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021133781', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021133806', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021133832', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021133903', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021133909', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021134127', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021134147', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021134327', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021134328', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021134384', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021134412', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021134494', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021134535', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021134560', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021134981', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021135120', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021135213', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021135241', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135269', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135329', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021135336', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021135390', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021135404', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021135455', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021135463', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021135594', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021135699', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021135752', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021135754', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021135867', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021135907', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021136011', (('Female', 'Pune'), ('PC001 PC005 PC033', 257))),
#  ('IND2021136016', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021136041', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021136059', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021136220', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021136260', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021136299', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021136425', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021136596', (('Female', 'Pune'), ('PC001 PC005 PC033', 173))),
#  ('IND2021136706', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021136887', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021136930', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021136947', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021136961', (('Female', 'Pune'), ('PC001 PC005 PC033', 250))),
#  ('IND2021137006', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021137042', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021137058', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021137101', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021137108', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021137164', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021137184', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021137270', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021137303', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021137328', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021137346', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021137441', (('Female', 'Pune'), ('PC001 PC005 PC033', 171))),
#  ('IND2021137488', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021137565', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021137745', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021137780', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021137819', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021137886', (('Female', 'Pune'), ('PC001 PC005 PC033', 176))),
#  ('IND2021137894', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021137964', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021137974', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021138001', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021138201', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021138208', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021138403', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021138418', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021138420', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021138463', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021138592', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021138613', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021138621', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021138656', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021138698', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021138749', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021138766', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021138854', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021138890', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021138927', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021138937', (('Female', 'Pune'), ('PC001 PC005 PC033', 253))),
#  ('IND2021138948', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021139085', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021139178', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021139271', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021139308', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139445', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021139487', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021139489', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139584', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021139587', (('Female', 'Pune'), ('PC001 PC005 PC033', 242))),
#  ('IND2021139629', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021139677', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021139738', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021140068', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021140238', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021140256', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021140390', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021140412', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021140439', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021140448', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021140481', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021140485', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021140488', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021140498', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021140604', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021140616', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021140662', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021140697', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021140843', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021140890', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021140897', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021140950', (('Female', 'Pune'), ('PC001 PC005 PC033', 238))),
#  ('IND2021140981', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021141020', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
# ...
#  ('IND2021146437', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021146460', (('Female', 'Pune'), ('PC001 PC005 PC033', 188))),
#  ('IND2021146556', (('Female', 'Pune'), ('PC001 PC005 PC033', 178))),
#  ('IND2021146597', (('Female', 'Pune'), ('PC001 PC005 PC033', 163))),
#  ('IND2021146709', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146746', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021146766', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021146857', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146892', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021146920', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021146936', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021146969', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021146973', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021146976', (('Female', 'Pune'), ('PC001 PC005 PC033', 246))),
#  ('IND2021147044', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021147096', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021147133', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021147202', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021147313', (('Female', 'Pune'), ('PC001 PC005 PC033', 241))),
#  ('IND2021147393', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021147414', (('Female', 'Pune'), ('PC001 PC005 PC033', 169))),
#  ('IND2021147454', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021147458', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021147602', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021147650', (('Female', 'Pune'), ('PC001 PC005 PC033', 183))),
#  ('IND2021147659', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021147691', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021147700', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021147715', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021147730', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021147749', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021147862', (('Female', 'Pune'), ('PC001 PC005 PC033', 206))),
#  ('IND2021147908', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021147909', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021147913', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021147973', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021147976', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021148011', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021148040', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021148075', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021148090', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021148109', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021148198', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021148246', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021148295', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021148298', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021148317', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021148336', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021148384', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021148502', (('Female', 'Pune'), ('PC001 PC005 PC033', 239))),
#  ('IND2021148521', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021148543', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021148582', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021148611', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021148619', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021148652', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021148716', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021148821', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021148862', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021149021', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021149066', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021149075', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021149163', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021149218', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021149222', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021149224', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021149254', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021149316', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021149372', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021149440', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021149539', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021149741', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021149748', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021149844', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021149859', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021149965', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021150002', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021150109', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021150136', (('Female', 'Pune'), ('PC001 PC005 PC033', 180))),
#  ('IND2021150207', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021150268', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021150270', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021150319', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021150352', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021150361', (('Female', 'Pune'), ('PC001 PC005 PC033', 197))),
#  ('IND2021150614', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021150691', (('Female', 'Pune'), ('PC001 PC005 PC033', 233))),
#  ('IND2021150699', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021150707', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021150725', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021150764', (('Female', 'Pune'), ('PC001 PC005 PC033', 248))),
#  ('IND2021150767', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021150845', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021151091', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021151116', (('Female', 'Pune'), ('PC001 PC005 PC033', 179))),
#  ('IND2021151141', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021151163', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021151256', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021151339', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021151380', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021151381', (('Female', 'Pune'), ('PC001 PC005 PC033', 218))),
#  ('IND2021151435', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021151597', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021151626', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021151677', (('Female', 'Pune'), ('PC001 PC005 PC033', 216))),
#  ('IND2021151824', (('Female', 'Pune'), ('PC001 PC005 PC033', 198))),
#  ('IND2021151863', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021151980', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021152033', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021152096', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021152119', (('Female', 'Pune'), ('PC001 PC005 PC033', 177))),
#  ('IND2021152151', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021152185', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021152221', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021152238', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021152308', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021152365', (('Female', 'Pune'), ('PC001 PC005 PC033', 245))),
#  ('IND2021152382', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021152569', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021152714', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021152728', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021152782', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021152800', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021152951', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021152952', (('Female', 'Pune'), ('PC001 PC005 PC033', 237))),
#  ('IND2021152995', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021153108', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021153150', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021153301', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021153315', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021153316', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021153377', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021153410', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021153413', (('Female', 'Pune'), ('PC001 PC005 PC033', 204))),
#  ('IND2021153439', (('Female', 'Pune'), ('PC001 PC005 PC033', 191))),
#  ('IND2021153456', (('Female', 'Pune'), ('PC001 PC005 PC033', 226))),
#  ('IND2021153491', (('Female', 'Pune'), ('PC001 PC005 PC033', 217))),
#  ('IND2021153583', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021153697', (('Female', 'Pune'), ('PC001 PC005 PC033', 194))),
#  ('IND2021153778', (('Female', 'Pune'), ('PC001 PC005 PC033', 244))),
#  ('IND2021153856', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021154027', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021154064', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021154075', (('Female', 'Pune'), ('PC001 PC005 PC033', 168))),
#  ('IND2021154143', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021154161', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021154162', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021154290', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021154298', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021154502', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021154512', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021154551', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021154568', (('Female', 'Pune'), ('PC001 PC005 PC033', 234))),
#  ('IND2021154628', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021154672', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021154701', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021154755', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021154795', (('Female', 'Pune'), ('PC001 PC005 PC033', 221))),
#  ('IND2021154821', (('Female', 'Pune'), ('PC001 PC005 PC033', 182))),
#  ('IND2021154828', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021154839', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021154855', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021154862', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021154908', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021154937', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021154950', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021154956', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155008', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155197', (('Female', 'Pune'), ('PC001 PC005 PC033', 201))),
#  ('IND2021155242', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021155249', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021155289', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021155295', (('Female', 'Pune'), ('PC001 PC005 PC033', 213))),
#  ('IND2021155358', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021155415', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021155455', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021155485', (('Female', 'Pune'), ('PC001 PC005 PC033', 184))),
#  ('IND2021155488', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155497', (('Female', 'Pune'), ('PC001 PC005 PC033', 222))),
#  ('IND2021155537', (('Female', 'Pune'), ('PC001 PC005 PC033', 230))),
#  ('IND2021155627', (('Female', 'Pune'), ('PC001 PC005 PC033', 199))),
#  ('IND2021155767', (('Female', 'Pune'), ('PC001 PC005 PC033', 219))),
#  ('IND2021155797', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155811', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021155830', (('Female', 'Pune'), ('PC001 PC005 PC033', 232))),
#  ('IND2021155844', (('Female', 'Pune'), ('PC001 PC005 PC033', 208))),
#  ('IND2021155851', (('Female', 'Pune'), ('PC001 PC005 PC033', 190))),
#  ('IND2021155869', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021155877', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021155977', (('Female', 'Pune'), ('PC001 PC005 PC033', 211))),
#  ('IND2021156107', (('Female', 'Pune'), ('PC001 PC005 PC033', 196))),
#  ('IND2021156289', (('Female', 'Pune'), ('PC001 PC005 PC033', 228))),
#  ('IND2021156415', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021156465', (('Female', 'Pune'), ('PC001 PC005 PC033', 247))),
#  ('IND2021156471', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ('IND2021156500', (('Female', 'Pune'), ('PC001 PC005 PC033', 225))),
#  ('IND2021156516', (('Female', 'Pune'), ('PC001 PC005 PC033', 224))),
#  ('IND2021156520', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021156639', (('Female', 'Pune'), ('PC001 PC005 PC033', 200))),
#  ('IND2021156693', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021156821', (('Female', 'Pune'), ('PC001 PC005 PC033', 195))),
#  ('IND2021156887', (('Female', 'Pune'), ('PC001 PC005 PC033', 210))),
#  ('IND2021156956', (('Female', 'Pune'), ('PC001 PC005 PC033', 235))),
#  ('IND2021156983', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021157012', (('Female', 'Pune'), ('PC001 PC005 PC033', 215))),
#  ('IND2021157131', (('Female', 'Pune'), ('PC001 PC005 PC033', 189))),
#  ('IND2021157379', (('Female', 'Pune'), ('PC001 PC005 PC033', 181))),
#  ('IND2021157418', (('Female', 'Pune'), ('PC001 PC005 PC033', 236))),
#  ('IND2021157442', (('Female', 'Pune'), ('PC001 PC005 PC033', 174))),
#  ('IND2021157456', (('Female', 'Pune'), ('PC001 PC005 PC033', 209))),
#  ('IND2021157504', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021157555', (('Female', 'Pune'), ('PC001 PC005 PC033', 212))),
#  ('IND2021157784', (('Female', 'Pune'), ('PC001 PC005 PC033', 205))),
#  ('IND2021157790', (('Female', 'Pune'), ('PC001 PC005 PC033', 192))),
#  ('IND2021157825', (('Female', 'Pune'), ('PC001 PC005 PC033', 223))),
#  ('IND2021157887', (('Female', 'Pune'), ('PC001 PC005 PC033', 231))),
#  ('IND2021158119', (('Female', 'Pune'), ('PC001 PC005 PC033', 185))),
#  ('IND2021158174', (('Female', 'Pune'), ('PC001 PC005 PC033', 187))),
#  ('IND2021158303', (('Female', 'Pune'), ('PC001 PC005 PC033', 207))),
#  ('IND2021158369', (('Female', 'Pune'), ('PC001 PC005 PC033', 203))),
#  ('IND2021158389', (('Female', 'Pune'), ('PC001 PC005 PC033', 229))),
#  ('IND2021158725', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021158801', (('Female', 'Pune'), ('PC001 PC005 PC033', 193))),
#  ('IND2021158865', (('Female', 'Pune'), ('PC001 PC005 PC033', 220))),
#  ('IND2021158949', (('Female', 'Pune'), ('PC001 PC005 PC033', 202))),
#  ('IND2021158955', (('Female', 'Pune'), ('PC001 PC005 PC033', 227))),
#  ('IND2021159023', (('Female', 'Pune'), ('PC001 PC005 PC033', 186))),
#  ('IND2021159208', (('Female', 'Pune'), ('PC001 PC005 PC033', 214))),
#  ...]

# %% [markdown]
# ---
#
# ![](images/data_of_pune_persist_1.png)
#
#
# ---
